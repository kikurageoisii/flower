# %% [markdown]
# ## 目次:
# * [演習2.1](#2.1)
# * [演習2.2](#2.2)
# * [演習2.3](#2.3)
# * [演習2.4](#2.4)
# * [演習2.5](#2.5)
# * [演習2.6](#2.6)
# * [演習2.7](#2.7)

# %% [markdown]
# <a class = "anchor" id = "2.1"></a>
# **【演習 2.1】**
# 次のプログラムには誤りがあります。正しく動作するように、プログラムを完成させてください。

# %%
a="3"
b="5"
c=a+b
print(c)
# Out:
# 35

# %%
a="3"
b="5"
c=???
print(c)

# %% [markdown]
# <a class = "anchor" id = "2.2"></a>
# **【演習 2.2】**
# 割り切れる四則演算なのに、なぜか「.0」の表記が発生してしまいました。
# 出力が整数になるよう修正を加えてください。修正の方法は問いませんが、直接y=6と宣言する事は禁止とします。

# %%
y=3*8/4
print(y)
# Out:
# 6.0

# %%
y=3*8/4
y=???
print(y)

# %% [markdown]
# <a class = "anchor" id = "2.3"></a>
# **【演習 2.3】**
# 令和の総理大臣リストを作る際に、誤って菅総理を2回入力してしまいました。
# リストの作成部分はそのままで、リストを操作して重複を取り除いて下さい。

# %%
primers=["安部晋三","菅義偉","菅義偉"]
???
print(primers)

# %% [markdown]
# <a class = "anchor" id = "2.4"></a>
# **【演習 2.4】**
# リストのメソッドを用いて、リストの最後に[岸田文雄]を追加してください。

# %%
primers=["安部晋三","菅義偉"]
???
print(primers)

# %% [markdown]
# <a class = "anchor" id = "2.5"></a>
# **【演習 2.5】**
# リストの中の一番小さい値を出力するように、以下のプログラムを完成させてください。

# %%
a=[73,84,41,36,85,36,78,99,57,35]
???
print(???)

# %% [markdown]
# <a class = "anchor" id = "2.6"></a>
# **【演習 2.6】**
# リストの4番目の要素である「生田」を出力しようとしたら、エラーが出力されました。4番目の要素である「生田」を出力するように、修正してください。

# %%
station=["新百合ヶ丘","百合ヶ丘","読売ランド前","生田"]
print(station[4])
# Out:
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# <ipython-input-1-88c1e8e2a87f> in <module>
#       1 station=["新百合ヶ丘","百合ヶ丘","読売ランド前","生田"]
# ----> 2 print(station[4])
#
# IndexError: list index out of range

# %% [markdown]
# <a class = "anchor" id = "2.7"></a>
# **【演習 2.7】**
# 小田急小田原線の路線図のリストstationがある。
# 1. 駅の総数をprintしてください。
# 2. 新宿から下北沢までの駅をprintしてください。
# 3. 相模大野から登戸までの駅をprintしてください。ただし、先頭が相模大野になるようにしてください。

# %%
station=['新宿', '南新宿', '参宮橋', '代々木八幡', '代々木上原', '東北沢', '下北沢', '世田谷代田', '梅ヶ丘', '豪徳寺', '経堂', '千歳船橋', '祖師ヶ谷大蔵', '成城学園前', '喜多見', '狛江', '和泉多摩川', '登戸', '向ヶ丘遊園', '生田', '読売ランド前', '百合ヶ丘', '新百合ヶ丘', '柿生', '鶴川', '玉川学園前', '町田', '相模大野', '小田急相模原', '相武台前', '座間', '海老名', '厚木', '本厚木', '愛甲石田', '伊勢原', '鶴巻温泉', '東海大学前', '秦野', '渋沢', '新松田', '開成', '栢山', '富水', '螢田', '足柄', '小田原']

# %%
#1
print(???)

#2
print(???)

#3
print(???)
