# %% [markdown]
# ## 目次:
# * [演習3.1.1](#3.1.1)
# * [演習3.1.2](#3.1.2)
# * [演習3.2.1](#3.2.1)
# * [演習3.2.2](#3.2.2)
# * [演習3.3.1](#3.3.1)
# * [演習3.3.2](#3.3.2)
# * [演習3.3.3](#3.3.3)
# * [演習3.3.4](#3.3.4)
# * [演習3.4.1](#3.4.1)
# * [演習3.4.2](#3.4.2)

# %% [markdown]
# <a class = "anchor" id = "3.1.1"></a>
# **【演習 3.1.1】**
# 入力した自然数が3の倍数のときに”Fizz” 、5の倍数のときに”Buzz”、15の倍数のときに”FizzBuzz”、それ以外のときは、数字をそのまま出力するようなプログラムを作成してください。

# %%
n = int(???())

if ???:
    print(???)
elif ???:
    print(???)
elif ???:
    print(???)
else:
    print(n)

# %% [markdown]
# <a class = "anchor" id = "3.1.2"></a>
# **【演習 3.1.2】**
# BMIを入力として、体型を判定するプログラムを作成してください。
# 18.5未満を低体重、18.5以上25未満を普通体重、25以上を肥満とします。

# %%
bmi = float(???("BMIを入力してください:"))

if ???:
    print("低体重")
elif ???:
    print("普通体重")
else:
    print("肥満")

# %% [markdown]
# <a class = "anchor" id = "3.2.1"></a>
# **【演習 3.2.1】**
# [演習3.1.1](#3.1.1)のプログラムを、1から100までの結果をすべて出力するプログラムに変更してください。

# %%
for i ???:
    if ???:
        print(???)
    elif ???:
        print(???)
    elif ???:
        print(???)
    else:
        print(i)

# %% [markdown]
# <a class = "anchor" id = "3.2.2"></a>
# **【演習 3.2.2】**
# 次に示すリストaの要素の合計値を出力するようなプログラムを作成してください。<br>
# a = [2.7, 5.5, 3.9, 5, 9, 2.3, 2.4, 6.0]

# %%
a = [2.7, 5.5, 3.9, 5, 9, 2.3, 2.4, 6.0]

total = 0

for i ???:
    total += ???

print("要素の合計は",total)

# %% [markdown]
# <a class = "anchor" id = "3.3.1"></a>
# **【演習 3.3.1】**
# 「Mercury, Venus, Earth, Mars, Jupiter, Saturn, Uranus, Neptune」を要素にもつ太陽系のリストSolar_Systemを用いて、各惑星に対して太陽から何番目に近いかを出力するプログラムを作成してください。

# %%
Solar_System = ["Mercury", "Venus", "Earth", "Mars",
                "Jupiter", "Saturn", "Uranus", "Neptune"]

for i ???:
    print("{}は太陽から{}番目に近い惑星です.".format(???,???))

# %% [markdown]
# <a class = "anchor" id = "3.3.2"></a>
# **【演習 3.3.2】**
# 身長と体重という引数を持ち、その引数をもとにBMIを計算して、その結果を呼び出し元に返すユーザー定義関数calc_BMI(height, weight)を作成してください。
# - 引数である身長と体重はそれぞれheight、weightという変数で表してください。
# - BMIの計算式は、次の通りです。
# $$
#                            BMI = 体重[kg] / (身長[m])^2
# $$
# - BMIを計算後、Pythonの組み込み関数の一つであるround関数で、小数点第一位まで丸めてください。

# %%
# round関数の例
# 小数点第一位で丸める場合
i = 23.855
print(round(i, 1))

# %%
def ???:
    
    bmi = ???
    
    return ???

# %%
bmi = calc_BMI(175, 60)
print("BMIは{}です.".format(bmi))

# %% [markdown]
# <a class = "anchor" id = "3.3.3"></a>
# **【演習 3.3.3】**
# BMIを計算して、それをもとに判定結果を出力するユーザー定義関数eval_body()を作成してください。
# - 判定結果の分岐は[演習3.1.2](#3.1.2)と同様に、
# 　　　　18.5未満を低体重、18.5以上25未満を普通体重、25以上を肥満
# とします。
# - eval_body関数内でcalc_BMI関数を呼び出して、BMIを計算してください。ただし、身長と体重は、関数の外でグローバル変数として定義しています。

# %%
height = 175
weight = 60

def eval_body():
    bmi = ???
    if ???:
        print("判定 : 低体重です。")
    elif ???:
        print("判定 : 普通体重です。")
    else:
        print("判定 : 肥満です。")

???

# %% [markdown]
# <a class = "anchor" id = "3.3.4"></a>
# **【演習 3.3.4】**
# オイラー関数φ(n)とは、正の整数nに対してn未満で、nと互いに素であるような自然数の個数を返す関数です。2数が互いに素であるとは、2数の最大公約数が1であることを意味します。次の各問に沿って、オイラー関数φ(n)を計算して出力するプログラムを作成してください。
#
# 1. 受け取った2つの自然数の最大公約数を返す関数gcd(a,b)を作成してください。
#
# 2. (1)で作成した関数を使って、受け取った2つの自然数が互いに素であるかを判定し、互いに素であればTrue、そうでなければFalseを返す関数is_coprime(a,b)を作成してください。
#
# 3. (2)で作成した関数を使って、オイラー関数euler(n)を作成し、1から30までのオイラー関数の値を確認するプログラムを作成してください。

# %%
# (1)
def gcd(a, b):
    r = ???          # r:余り
    while(???):     # rが0になるまで繰り返す
        ???          # 割る数を割られる数に移動
        ???          # 余りを割る数に移動
        r = ???
    return ???      # rが0になったときの割る数を返す

# %%
print(gcd(572, 638))

# %%
# (2)
def is_coprime(a, b):
    c = ???      #2数の最大公約数を保持
    if(???):     #互いに素であることは最大公約数が1であることに等しい
        return ???
    else:
        return ???

# %%
# (3)
def euler(n):
    count = 0        #個数を数えるための変数を用意
    for i ???:      #1からn未満までの数に対して互いに素か判定
        if(???):    #互いに素ならカウント
            count += 1
    return count    #互いに素な数の個数を返す

# %%
for i in range(1, 31):
    print("φ({}) = {}".format(i, euler(i)))

# %% [markdown]
# <a class = "anchor" id = "3.4.1"></a>
# **【演習 3.4.1】**
# ある人物の名前、年齢、身長、体重を変数にもつPersonクラスを作成します。Personクラスに関する次のプログラムを完成させてください。なお, Personクラス内の各メソッドは次の通りです。
# - set_weightメソッド : リスト型で与えた体重データをself.weightに結合する。
# - set_heightメソッド : リスト型で与えた身長データをself.heightに結合する。
# - describeメソッド   : 名前,年齢,現在の体重・身長を表示する。

# %%
class Person():
    def __init__(self, name, age):
        self.name = ???         
        self.age = ???    
        self.weight = []
        self.height = []
    
    # 体重を記録する
    def set_weight(???, weight):
        ???.???.extend(???)
    
    # 身長を記録する
    def set_height(???, height):
        ???.???.extend(???) 
    
    def describe(self):
        print("名前 : {}, 年齢 : {}".format(self.name, self.age))
        print("{}さんの現在の体重は{}kgです。".format(self.name, self.weight[-1]))
        print("{}さんの現在の身長は{}cmです。".format(self.name, self.height[-1]))

# %%
# サンプルコード
taro = Person("Taro", 20)
taro.set_weight([60.6, 61.2, 62.7, 65.8])
taro.set_height([175.0, 175.2, 175.3, 175.6])
taro.describe()

# %%
# extendメソッドの例
x = [1, 2, 3]
x.extend([4, 5, 6])
print(x)

# %% [markdown]
# <a class = "anchor" id = "3.4.2"></a>
# **【演習 3.4.2】**
# [演習3.3.2](#3.3.2)で作成したcalc_BMI関数を、Personクラスのメソッドとして組み込んでください。ただし、calc_BMIメソッドでは、次の仕様を追加してください。
# - 最新のBMIの値を出力する場合と、今までのBMIをリストとして出力する場合で、条件分岐を行う。
# - 条件分岐の条件は、引数から指定できるようにする。
#
# calc_BMIメソッドが完成したら、describeメソッドで呼び出して、最新のBMIを出力するように、describeメソッドを書き換えてください。

# %% [markdown]
# ※[演習3.4.1](#3.4.1)用のセルに追記してください。

# %%
# サンプルコード
taro = Person("Taro", 20)
taro.set_weight([60.6, 61.2, 62.7, 65.8])
taro.set_height([175.0, 175.2, 175.3, 175.6])
taro.describe()
