# %% [markdown]
# # 3章演習 グラフ描画トレーニング

# %%
# 以下のライブラリを使うので、あらかじめ読み込んでおいてください
import numpy as np
import numpy.random as random

# 可視化ライブラリ
import matplotlib.pyplot as plt
import matplotlib as mpl
# %matplotlib inline

# 小数第３位まで表示
# %precision 3

# %% [markdown]
# # 3章演習 ①東京の降水量を比較してみよう
#
# ### 東京の降水量
#
# - 1991年から2020年までの月ごとの平均降水量(mm)
#
# |  1月  |  2月  |  3月  |  4月  |  5月  |  6月  |  7月  |  8月  |  9月  |  10月  |  11月  |  12月  |
# | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: |:----: |:----: |
# |  59.7  |  56.5 |  116.0  |  133.7  |   139.7  |  167.8 |  156.2  |  154.7  |   224.9  |  234.8  | 96.3  |57.9  |
#
# (https://www.data.jma.go.jp/obd/stats/etrn/view/nml_sfc_ym.php?prec_no=44&block_no=47662&year=&month=&day=&view=)
#
# - 2021年の月ごとの降水量(mm)
#
#
# |  1月  |  2月  |  3月  |  4月  |  5月  |  6月  |  7月  |  8月  |  9月  |  10月  |  11月  |  12月  |
# | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: |:----: |:----: |
# |  43.5  |  88.5 |  173.0  |  156.0  |   99.5  |  168.5 |  310.0 |  382.5  |  222.5  | 199.5  | 93.0  | 54.5  |
#
#
# (https://www.data.jma.go.jp/obd/stats/etrn/view/monthly_s1.php?prec_no=44&block_no=47662&year=2021&month=&day=&view=p1)

# %%
#データの準備
y1 = np.array([59.7, 56.5, 116.0, 133.7, 139.7, 167.8, 156.2, 154.7, 224.9, 234.8, 96.3, 57.9])
y2 = np.array([43.5, 88.5, 173.0, 156.0, 99.5, 168.5, 310.0, 382.5, 222.5, 199.5, 93.0, 54.5])

# X軸のデータ
#######################ここにコードを書く##########################

###################################################################

# グラフの幅
w = 0.4

# グラフの大きさ指定(10,6)にしましょう
#######################ここにコードを書く##########################

###################################################################

# グラフの描画。y2はグラフの幅wの分、右にずらして描画する 
# y1のラベルは'Average'、y2のラベルは'2021'などわかりやすく
#######################ここにコードを書く##########################


###################################################################

# 凡例を最適な位置に配置
plt.legend(loc = 'best')

# 棒グラフのラベル表示
# ラベルは['Jan', 'Feb', 'Mar', 'Apr', 'May', 'Jun', 'Jul', 'Aug', 'Sep', 'Oct', 'Nov', 'Dec']
#######################ここにコードを書く##########################

###################################################################

# 軸ラベル
plt.xlabel('Month')
plt.ylabel('Precipitation amount (mm)')

# グラフタイトル
plt.title('Tokyo')

# グリッド表示
plt.grid(True)

# %% [markdown]
# # 3章演習 ②日本の貿易内訳を知ろう
#
# - 2020年度における日本の主な輸入相手国(億円)
#
# |  中国  |  アメリカ  |  オーストラリア  |  台湾  |  韓国  |  タイ  |  ベトナム  |  ドイツ  |  サウジアラビア  |  アラブ首長国連邦  |  総輸入総額  |
# | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: |
# |  175,077  |  74,536  |  38,313  |  28,629  |  28,416  |  25,401  |  23,551  |  22,763  |  19,696  |  17,502  | 680,108  |
#
# (https://www.digima-japan.com/knowhow/world/18506.php)
#
# (https://www.customs.go.jp/toukei/suii/html/time_latest.htm)

# %%
# 内容を表すラベルのリスト
labels = ['CHN', 'USA', 'AUS', 'TWN', 'KOR', 'THA', 'VNM', 'DEU', 'SAU', 'ARE','OTH']

# 上位10ヵ国以外の合計
others=226224

# データのリスト
sizes = [175077,74536,38313,28629,28416,25401,23551,22763,19696,17502,others]

# 色のリスト
colors = ['red', 'yellow', 'blue','yellowgreen', 'lightcoral', 'gold', 'lightskyblue', 'green', 'Cyan', 'Magenta', 'gray']

# グラフの大きさ指定(8,8)にしましょう
#######################ここにコードを書く##########################

###################################################################

# グラフを表示
#######################ここにコードを書く##########################

###################################################################

#グラフタイトル
plt.title('Import')

# 円を丸く描画
#######################ここにコードを書く##########################

###################################################################

# %% [markdown]
# # 3章演習 ③企業を分析してみよう
#
# - 企業6社の財務情報
#
# |    |  A社  |  B社  |  C社  |  D社  |  E社  |  F社  |
# | :----: | :----: | :----: | :----: | :----: | :----: |:----: |
# | 売上高(百万円)  |  10,264,602 |  3,336,967  |  4,476,758  |   3,014,095  | 3,586,839 |7,388,791 |
# | 営業利益率(%)  |  7.19 |  4.76  | 5.63 |   4.40  |  6.11 | 4.84 |
# | 時価総額(百万円)  |  6,414,556 |  2,486,212  |  3,054,394  | 1,402,448  | 3,994,100 |2,805,996 |

# %%
# データラベル作成
labels = ['A', 'B', 'C', 'D', 'E', 'F']

# 売上高と営業利益率を格納
x = np.array([10264602,3336967,4476758,3014095,3586839,7388791]) 
y = np.array([7.19,4.76,5.63, 4.40, 6.11,4.84 ]) 

# グラフの大きさ指定(10,6)にしましょう
#######################ここにコードを書く##########################

###################################################################

# 円のサイズ(時価総額)を格納
size = [ 6414556,2486212,3054394,1402448,3994100,2805996 ] 
#配列全体に1/10000倍
#######################ここにコードを書く##########################

###################################################################

# 軸ラベル
plt.xlabel('Sales (millions)')
plt.ylabel('Operating Margin Ratio (%)')

# 散布図を描画
#######################ここにコードを書く##########################

###################################################################

#データ名を記述
for i, label in enumerate(labels):
    plt.text(x[i]+100000, y[i]-0.1,label)

#グラフタイトル
plt.title('Financial information')

plt.grid(True)

# %% [markdown]
# # 3章演習 ～コラム～
#
# ### 資料1.函館の降水量
#
# - 1991年から2020年までの月ごとの平均降水量(mm)
#
# |  1月  |  2月  |  3月  |  4月  |  5月  |  6月  |  7月  |  8月  |  9月  |  10月  |  11月  |  12月  |
# | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: |:----: |:----: |
# |  77.4  |  64.5 |  64.1  |  71.9  |   88.9  |  79.8 |  123.6  |  156.5  |  150.5  |  150.6  | 110.8  | 94.6  |
#
# (https://www.data.jma.go.jp/obd/stats/etrn/view/nml_sfc_ym.php?prec_no=23&block_no=47430&year=2021&month=&day=&view=p1)
#
# - 2021年の月ごとの降水量(mm)
#
#
# |  1月  |  2月  |  3月  |  4月  |  5月  |  6月  |  7月  |  8月  |  9月  |  10月  |  11月  |  12月  |
# | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: |:----: |:----: |
# |  85.5  |  89.0 |  89.0  |  90.5  |  112.5 |  86.5 |  26.5 | 226.0 | 50.0  | 81.5  | 209.5  | 109.0  |
#
#
# (https://www.data.jma.go.jp/obd/stats/etrn/view/monthly_s1.php?prec_no=23&block_no=47430&year=2021&month=&day=&view=p1)
#
#
#
#
# ### 資料2.2020年度における日本の主な輸出相手国(億円)
#
# | 中国 | アメリカ | 韓国 | 台湾 | 香港 | タイ | シンガポール | ドイツ | ベトナム  |  マレーシア  |  総輸出総額  |
# | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: | :----: |
# |  150,820  |  126,108  |  47,665  |  47,391  | 34,146  |  27,226  |  18,876  | 18,752  |  18,258  |  13,435  | 683,991  |
#
# (https://www.digima-japan.com/knowhow/world/18506.php)
#
# (https://www.customs.go.jp/toukei/suii/html/time_latest.htm)
